# %%
from bs4 import BeautifulSoup as soup
from urllib.request import urlopen as uReq
 


my_url= "https://www.newegg.com/Product/ProductList.aspx?Submit=ENE&N=100007709%2050001312%2050001314%2050001315%2050001402%2050001419%2050001471%2050001561%2050001944%2050012150%204814%20601201888%20601204369%20601301599%20601296379%20601296377%2050001669%20601321570%20601321572%20601323902%20601328427%20601331000%20601331379&IsNodeId=1&cm_sp=Cat_video-Cards_1-_-Visnav-_-Gaming-Video-Cards_2"

#Opens up a connection
uClient = uReq(my_url)
page_html = uClient.read()
uClient.close()


# html parsing
page_soup = soup(page_html, "html.parser")

# %%
# We can see the several differnt html tags here
#Examples of tags are h1,h3,p, body.span etc. 
page_soup.p
# Out:
# <p>Newegg.com - A great place to buy computers, computer parts, electronics, software, accessories, and DVDs online. With great prices, fast shipping, and top-rated customer service - Newegg shopping upgraded ™</p>

# %%
#Grabs each product
containers = page_soup.findAll("div",{"class":"item-container"})

# %%
#can check length of containers
#len(containers)
container = containers[0]

divWithInfo = containers[0].find("div","item-info")

#iterative for loop

for container in containers: 
    brand = divWithInfo.div.a.img["title"]
    
    title_container = container.findAll("a", {"class":"item-title"})
    product_name = title_container[0].text
    
    shipping_container = container.findAll("li", {"class" :"price-ship" })
    shipping_container[0].text.strip()
    
    
    print("Brand: " + str(brand))
    print("Product name: " + str(product_name))
    print("Shipping option: " + str(shipping_container))
# Out:
# Brand: GIGABYTE
# Product name: GIGABYTE GeForce GTX 1660 Ti WINDFORCE OC 6G Graphics Card, 2 x WINDFORCE Fans, 6GB 192-Bit GDDR6, GV-N166TWF2OC-6GD Video Card
# Shipping option: [<li class="price-ship">
#         Free Shipping
#     </li>]
# Brand: GIGABYTE
# Product name: ASUS Dual GeForce GTX 1660 Ti DUAL-GTX1660TI-O6G 6GB 192-Bit GDDR6 PCI Express 3.0 HDCP Ready Video Card
# Shipping option: [<li class="price-ship">
#         Free Shipping
#     </li>]
# Brand: GIGABYTE
# Product name: GIGABYTE Radeon RX 570 DirectX 12 GV-RX570GAMING-4GD 4GB 256-Bit GDDR5 PCI Express 3.0 x16 CrossFireX Support ATX Video Card
# Shipping option: [<li class="price-ship">
#         Free Shipping
#     </li>]
# Brand: GIGABYTE
# Product name: MSI GeForce GTX 1660 Ti GTX 1660 TI GAMING X 6G 6GB 192-Bit GDDR6 PCI Express 3.0 Video Card
# Shipping option: [<li class="price-ship">
#         Free Shipping
#     </li>]
# Brand: GIGABYTE
# Product name: PowerColor RED DRAGON Radeon RX 580 DirectX 12 AXRX 580 8GBD5-3DHDV2/OC 8GB 256-Bit GDDR5 PCI Express 3.0 CrossFireX Support ATX Video Card
# Shipping option: [<li class="price-ship">
#         Free Shipping
#     </li>]
# Brand: GIGABYTE
# Product name: GIGABYTE Geforce RTX 2060 Gaming OC 6G Graphics Card, 3 x WINDFORCE Fans, 6GB 192-Bit GDDR6, GV-N2060GAMING OC-6GD Video Card
# Shipping option: [<li class="price-ship">
#         Free Shipping
#     </li>]
# Brand: GIGABYTE
# Product name: ASUS ROG GeForce RTX 2070 DirectX 12 ROG-STRIX-RTX2070-O8G-GAMING 8GB 256-Bit GDDR6 PCI Express 3.0 HDCP Ready Video Card
# Shipping option: [<li class="price-ship">
#         Free Shipping
#     </li>]
# Brand: GIGABYTE
# Product name: EVGA GeForce GTX 1660 Ti XC Black GAMING, 06G-P4-1261-KR, 6GB GDDR6, HDB Fan
# Shipping option: [<li class="price-ship">
#         Free Shipping
#     </li>]
# Brand: GIGABYTE
# Product name: GIGABYTE GeForce RTX 2080 GAMING OC 8G Graphics Card, 3 x WINDFORCE Fans, 8GB 256-Bit GDDR6, GV-N2080GAMING OC-8GC Video Card
# Shipping option: [<li class="price-ship">
#         Free Shipping
#     </li>]
# Brand: GIGABYTE
# Product name: ASUS Turbo GeForce GTX 1070 Ti TURBO-GTX1070TI-8G 8GB 256-Bit GDDR5 PCI Express 3.0 HDCP Ready SLI Support Video Card
# Shipping option: [<li class="price-ship">
#         Free Shipping
#     </li>]
# Brand: GIGABYTE
# Product name: GIGABYTE GeForce GTX 1060 DirectX 12 GV-N1060WF2OC-3GD 3GB 192-Bit GDDR5 PCI Express 3.0 x16 ATX Video Card
# Shipping option: [<li class="price-ship">
#         Free Shipping
#     </li>]
# Brand: GIGABYTE
# Product name: ZOTAC GAMING GeForce RTX 2060 AMP 6GB GDDR6 192-bit Gaming Graphics Card, Super Compact, IceStorm 2.0, ZT-T20600D-10M
# Shipping option: [<li class="price-ship">
#         Free Shipping
#     </li>]
# Brand: GIGABYTE
# Product name: MSI GeForce RTX 2080 DirectX 12 RTX 2080 VENTUS 8G OC 8GB 256-Bit GDDR6 PCI Express 3.0 x16 HDCP Ready SLI Support Video Card
# Shipping option: [<li class="price-ship">
#         Free Shipping
#     </li>]
# Brand: GIGABYTE
# Product name: GIGABYTE GeForce RTX 2070 WINDFORCE 8G Graphics Card, 3 x WINDFORCE Fans, 8GB 256-Bit GDDR6, GV-N2070WF3-8GC Video Card
# Shipping option: [<li class="price-ship">
#         Free Shipping
#     </li>]
# Brand: GIGABYTE
# Product name: GIGABYTE GeForce RTX 2060 WINDFORCE OC 6G Graphics Card, 2 x WINDFORCE Fans, 6GB 192-Bit GDDR6, GV-N2060WF2OC-6GD Video Card
# Shipping option: [<li class="price-ship">
#         Free Shipping
#     </li>]
# Brand: GIGABYTE
# Product name: EVGA GeForce RTX 2060 XC BLACK GAMING, 6GB GDDR6, HDB Fan Graphics Card 06G-P4-2061-KR
# Shipping option: [<li class="price-ship">
#         Free Shipping
#     </li>]
# Brand: GIGABYTE
# Product name: ASUS ROG GeForce RTX 2070 DirectX 12 ROG-STRIX-RTX2070-A8G-GAMING 8GB 256-Bit GDDR6 PCI Express 3.0 HDCP Ready Video Card
# Shipping option: [<li class="price-ship">
#         Free Shipping
#     </li>]
# Brand: GIGABYTE
# Product name: GIGABYTE GeForce RTX 2070 GAMING OC 8G Graphics Card, 3 x WINDFORCE Fans, 8GB 256-Bit GDDR6, GV-N2070GAMING OC-8GC Video Card
# Shipping option: [<li class="price-ship">
#         Free Shipping
#     </li>]
# Brand: GIGABYTE
# Product name: ASUS GeForce GTX 1050 Ti PH-GTX1050TI-4G 4GB 128-Bit GDDR5 PCI Express 3.0 HDCP Ready Video Card
# Shipping option: [<li class="price-ship">
#         Free Shipping
#     </li>]
# Brand: GIGABYTE
# Product name: EVGA GeForce RTX 2080 Ti FTW3 ULTRA GAMING, 11G-P4-2487-KR, 11GB GDDR6, iCX2 & RGB LED
# Shipping option: [<li class="price-ship">
#         Free Shipping
#     </li>]
# Brand: GIGABYTE
# Product name: ASUS Turbo GeForce RTX 2080 DirectX 12 TURBO-RTX2080-8G 8GB 256-Bit GDDR6 PCI Express 3.0 HDCP Ready Video Card
# Shipping option: [<li class="price-ship">
#         Free Shipping
#     </li>]
# Brand: GIGABYTE
# Product name: MSI GeForce RTX 2070 DirectX 12 RTX 2070 GAMING Z 8G 8GB 256-Bit GDDR6 PCI Express 3.0 x16 HDCP Ready Video Card
# Shipping option: [<li class="price-ship">
#         $3.99 Shipping
#     </li>]
# Brand: GIGABYTE
# Product name: PowerColor RED DEVIL Radeon RX 570 DirectX 12 AXRX 570 4GBD5-3DH/OC 4GB 256-Bit GDDR5 PCI Express 3.0 CrossFireX Support ATX Video Card
# Shipping option: [<li class="price-ship">
#         Free Shipping
#     </li>]
# Brand: GIGABYTE
# Product name: ZOTAC GAMING GeForce RTX 2060 Twin Fan 6GB GDDR6 192-bit Gaming Graphics Card, Super Compact, IceStorm 2.0, ZT-T20600F-10M
# Shipping option: [<li class="price-ship">
#         Free Shipping
#     </li>]
# Brand: GIGABYTE
# Product name: GIGABYTE AORUS Radeon RX 580 DirectX 12 GV-RX580AORUS-4GD 4GB 256-Bit GDDR5 PCI Express 3.0 x16 CrossFireX Support ATX Video Card
# Shipping option: [<li class="price-ship">
#         Free Shipping
#     </li>]
# Brand: GIGABYTE
# Product name: EVGA GeForce GTX 1660 Ti XC GAMING, 06G-P4-1263-KR, 6GB GDDR6, HDB Fan
# Shipping option: [<li class="price-ship">
#         Free Shipping
#     </li>]
# Brand: GIGABYTE
# Product name: GIGABYTE Geforce RTX 2060 OC GG Graphics Card, 2 x WINDFORCE Fans, 6GB 192-Bit GDDR6, GV-N2060OC-6GD rev 2.0 Video Card
# Shipping option: [<li class="price-ship">
#         Free Shipping
#     </li>]
# Brand: GIGABYTE
# Product name: ASUS Turbo GeForce GTX 1070 TURBO-GTX1070-8G 8GB 256-Bit GDDR5 PCI Express 3.0 HDCP Ready SLI Support Video Card
# Shipping option: [<li class="price-ship">
#         Free Shipping
#     </li>]
# Brand: GIGABYTE
# Product name: ASUS Turbo GeForce RTX 2060 DirectX 12 TURBO-RTX2060-6G 6GB 192-Bit GDDR6 HDCP Ready Video Card
# Shipping option: [<li class="price-ship">
#         Free Shipping
#     </li>]
# Brand: GIGABYTE
# Product name: GIGABYTE AORUS GeForce RTX 2080 TI DirectX 12 GV-N208TAORUS X-11GC Video Card
# Shipping option: [<li class="price-ship">
#         Free Shipping
#     </li>]
# Brand: GIGABYTE
# Product name: ASUS Dual GeForce RTX 2070 DirectX 12 DUAL-RTX2070-O8G 8GB 256-Bit GDDR6 PCI Express 3.0 HDCP Ready Video Card
# Shipping option: [<li class="price-ship">
#         Free Shipping
#     </li>]
# Brand: GIGABYTE
# Product name: GIGABYTE AORUS RTX 2070 GAMING BOX GeForce RTX 2070 DirectX 12 GV-N2070IXEB-8GC 8GB 256-Bit GDDR6 PCI Express 3.0 x4 ATX Video Card
# Shipping option: [<li class="price-ship">
#         Free Shipping
#     </li>]
# Brand: GIGABYTE
# Product name: ASUS ROG GeForce GTX 1060 ROG-STRIX-GTX1060-A6G-GAMING 6GB 192-Bit GDDR5 PCI Express 3.0 HDCP Ready Video Card
# Shipping option: [<li class="price-ship">
#         Free Shipping
#     </li>]
# Brand: GIGABYTE
# Product name: PNY GeForce GTX 1070 Ti DirectX 12 VCGGTX1070T8PB-CG 8GB 256-Bit GDDR5 PCI Express 3.0 x16 HDCP Ready SLI Support Video Card
# Shipping option: [<li class="price-ship">
#         Free Shipping
#     </li>]
# Brand: GIGABYTE
# Product name: GIGABYTE GeForce RTX 2060 GAMING OC PRO 6G Graphics Card, 3 x WINDFORCE Fans, 6GB 192-Bit GDDR6, GV-N2060GAMINGOC PRO-6GD Video Card
# Shipping option: [<li class="price-ship">
#         Free Shipping
#     </li>]
# Brand: GIGABYTE
# Product name: ASUS DUAL RTX 2080 Overclocked Edition 8GB VR Ready Gaming Graphics Card - Turing Architecture (DUAL-RTX2080-O8G)
# Shipping option: [<li class="price-ship">
#         Free Shipping
#     </li>]

# %% [markdown]
# #Writing to a file
#
# filename = "products.csv"
# f = open(filename, "w")
# headers = "brand, product_name, shipping \n"
#
# f.write(headers)
# for container in containers:
#     brand = divWithInfo.div.a.img["title"]
#
#     title_container = container.findAll("a", {"class":"item-title"})
#     product_name = title_container[0].text
#
#     shipping_container = container.findAll("li", {"class" :"price-ship" })
#     shipping_container[0].text.strip()
#
#     print("brand: " + brand)
#     print("product name: " + product_name)
#     print("shipping option: " + shipping_container)
#
#     f.write(brand + ","+product_name.replace(",","|")+ ","+ shipping + "\n")
#
# f.close
